# %%
#payment app

# %%
import re
class Pkpay:
    def __init__(self):
        self.user_details={}
        self.wallet_money=0
        self.transaction_history={}
        self.transaction_id=len(self.transaction_history)+1
        
    def user_reg(self):
        try:
            
            while True:
                phone=input("Entre Your Phone Number: \n+91-")
                if phone.isnumeric()==True:
                    if len(phone)==10:
                        phone=int(phone)
                        break
                    else:
                        print( " __________________\n|!!Invalid Number!!|\n|__________________|")
                else:
                    print( " __________________\n|!!Invalid Number!!|\n|__________________|")
            Fname=input("Entre Your First Name:\n")
            Mname=input("Entre Your Middle Name:\n")
            Lname=input("Entre Your Last Name:\n")
            name= Fname+" "+Mname+" "+Lname
            while True:
                regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
                email=input("Entre Your Email Id: \n")
                if(re.fullmatch(regex, email)):
                    break
                else:
                    print( " __________________\n|!!Invalid email!! |\n|__________________|")
            while True:
                password=input("Entre Password")
                Check=False
                if len(password)>=8:
                    for i in password:
                        if i in ('@','#','!','$','%','&','^','*','(',')','_','-','+','?','/','~','<','>','*'):
                            Check=True
                        else:
                            pass
                    if Check==True:
                        break
                    else:
                        print("Password Must Contain Speacal Characters")
                else:
                    print("Password Must Contain 8 Characters")
            while True:
                DOB=input('Entre Your Birth Date DD/MM/YYYY')
                if DOB[0:2].isnumeric()==True and DOB[3:5].isnumeric()==True and DOB[6:10].isnumeric()==True:
                    if DOB[2]=="/" and DOB[5]=="/" and int(DOB[0:2])<=31 and int(DOB[3:5])<=12:
                        break
                    else:
                        print( " __________________\n|  !!Invalid DOB!! |\n|__________________|")
                else:
                    print( " __________________\n|  !!Invalid DOB!! |\n|__________________|")

            self.user_details={'NAME':name,'NUMBER':phone,'DOB':DOB,'EMAIL':email,'PASSWORD':password}
        except exception as e:
            print("Oops Something Went Wrong")
    def user_login(self,email,password):
        if len(self.user_details)>0:
            if self.user_details['EMAIL']==email and self.user_details['PASSWORD']==password:
                print("Welcome",self.user_details['NAME'])
                return True
            else:
                print( " __________________\n|!!Invalid Detail!!|\n|__________________|")
                return False
        print( " __________________\n|!!Invalid Detail!!|\n|__________________|") 
    def add_money(self):
        while True:
            ammount=input("Entre Ammount You want to add in Wallet")
            if ammount.isnumeric()==True:
                ammount=int(ammount)
                self.wallet_money+=ammount
                ttype="Wallet Recharge"
                number=self.user_details["NUMBER"]
                self.historyfun(number,ammount,ttype)
                break
            else:
                print( " __________________\n|!!Invalid Input !!|\n|__________________|")
    def Recharge(self):
        while True:
            carr=(input("Entre Carrier Name\nJIO\nAIRTEL\nVI:\n")).lower()
            listc=("airtel","jio","vi")
            if carr in listc:
                phone=input("Entre Your Phone Number: \n+91-")
                if phone.isnumeric()==True:
                    if len(phone)==10 :
                        phone=int(phone)
                        break
                    else:
                        print( " __________________\n|!!Invalid Number!!|\n|__________________|")
                else:
                    print( " __________________\n|!!Invalid Number!!|\n|__________________|")
            else:
                print( " __________________\n|!!Invalid Carrier!!|\n|__________________|")
                
        if self.wallet_money>0:
            while True:
                ame=input("Entre Plan Ammount:\n")
                if ame.isnumeric()==True:
                    ame=int(ame)
                    if ame<=self.wallet_money:
                        self.wallet_money-=ame
                        print( " __________________\n|!!Recharge Done !!|\n|__________________|")
                        ttype="Prepaid Recharge"
                        self.historyfun(phone,ame,ttype)
                        break
                    else:
                          print( " ___________________________\n| !!Insuffciant  Balance!!  |\n|___________________________|")
            else:
                print( " ___________________________\n| !!Insuffciant  Balance!!  |\n|___________________________|")

    def send_money(self):
        if self.wallet_money>0:
            while True:
                phone=input("Entre Recever's Phone Number: \n+91-")
                if phone.isnumeric()==True:
                    if len(phone)==10:
                        phone=int(phone)
                        break
                else:
                    print( " __________________\n|!!Invalid Number!!|\n|__________________|")
            else:
                print( " __________________\n|!!Invalid Number!!|\n|__________________|")
        while True:
            eamo=input("Entre Ammount: \n")
            if eamo.isnumeric()==True:
                eamo=int(eamo)
                break
            else:
                print( " __________________\n|!!Invalid Input !!|\n|__________________|")
        while True:
            cho=input("\n1.Conform\n2.Cancle\n")
            if cho=="1":
                if eamo<=self.wallet_money:
                    self.wallet_money-=eamo
                    print( " __________________\n|!!Transfer Done !!|\n|__________________|")
                    ttype="Send Money"
                    self.historyfun(phone,eamo,ttype)
                    break
                else:
                    print( " ___________________________\n| !!Insuffciant  Balance!!  |\n|___________________________|")
            elif cho=="2":
                break
            else:
                print( " __________________\n|!!Invalid Input !!|\n|__________________|")
    
    def view_profile(self):
        print(f"NAME: {self.user_details['NAME']}\n DOB: {self.user_details['DOB']}\n EMAIL: {self.user_details['EMAIL']}\n PHONE NUMBER: {self.user_details['NUMBER']}\n ")
    
    def edit_profile(self):
        try: 
            while True:
                password=input("Entre Password To Continue")
                if password==self.user_details["PASSWORD"]:
                    break
                else:
                    print("Wrong Password")
            while True:
                print("1.Edit Name\n2.Edit Email\n3.Edit Phone Number\n4.Change DOB\n5.Change Password\n6.Exit")
                getin=input("Entre Your Choice:\n")
                if getin=="1":
                    newname=input("Entre New Name")
                    self.user_details['NAME']=newname
                    print( " __________________\n| !!Name Updated!! |\n|__________________|")
                    break
                elif getin=="2":
                    while True:
                        regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
                        email=input("Entre New Email Id: \n")
                        if(re.fullmatch(regex, email)):
                            self.user_details["EMAIL"]==email
                            print( " __________________\n|!!Email Updated!! |\n|__________________|")
                            break
                        else:
                            print( " __________________\n|!!Invalid email!! |\n|__________________|")
                elif getin=="3":
                    while True:
                        phone=input("Entre New Phone Number: \n+91-")
                        if phone.isnumeric()==True:
                            if len(phone)==10:
                                phone=int(phone)
                                self.user_details["NUMBER"]=phone
                                print( " __________________\n|!!Number Updated!!|\n|__________________|")
                                break
                            else:
                                print( " __________________\n|!!Invalid Number!!|\n|__________________|")
                        else:
                                print( " __________________\n|!!Invalid Number!!|\n|__________________|")
                elif getin=="4":
                    while True:
                        DOB=input('Entre Your Birth Date DD/MM/YYYY')
                        if DOB[0:2].isnumeric()==True and DOB[3:5].isnumeric()==True and DOB[6:10].isnumeric()==True:
                            if DOB[2]=="/" and DOB[5]=="/" and int(DOB[0:2])<=31 and int(DOB[3:5])<=12:
                                self.user_details["DOB"]=DOB
                                print( " __________________\n|  !!DOB Updated!! |\n|__________________|")
                                break
                            else:
                                print( " __________________\n|  !!Invalid DOB!! |\n|__________________|")
                        else:
                            print( " __________________\n|  !!Invalid DOB!! |\n|__________________|")  

                elif getin=="5":
                    while True:
                        password=input("Entre Password")
                        Check=False
                        if len(password)>=8:
                            for i in password:
                                if i in ('@','#','!','$','%','&','^','*','(',')','_','-','+','?','/','~','<','>','*'):
                                    Check=True
                                else:
                                    pass
                                if Check==True:
                                    self.user_details['PASSWORD']=password
                                    print( " ____________________\n|!!Password Updated!!|\n|____________________|")

                                    break
                                else:
                                    print("Password Must Contain Speacal Characters")
                        else:
                            print("Password Must Contain min 8 Characters")
                elif getin=="6":
                    break

                else:
                    print( " __________________\n|!!Invalid Input !!|\n|__________________|")
                    
        except exception as e:
            print("Oops Something Went Wrong")    
                    
    def historyfun (self,number,ammount,ttype):
        self.transaction_history[self.transaction_id]={"NUMBER":number,"AMMOUNT":ammount,"TYPE":ttype,"BALANCE":self.wallet_money}
        self.transaction_id+=1
        
    
def driver_code():
    obj=Pkpay()
    try:
        
        while True:
            print("1.Registration\n2.Login\n3.Exit")
            uinput=input("Entre Your Choice")
            if uinput=="1":
                obj.user_reg()
            elif uinput=="2":
                email=input("Entre Your Registerd Email To Continue")
                password=input("Entre Your Password")
                if obj.user_login(email,password):
                    while True:
                        print("1.Show Wallet Balnace\n2.Add Money In Wallet\n3.Send Money\n4.Recharge Prepaid sim\n5.Show Profile\n6.Edit Profile\n7.Show Transaction History\n8.Logout")
                        uinput2=input("Entre Your Choice")
                        if uinput2=="1":
                            print(f"Your Current PK Wallet Balance is {obj.wallet_money}Rs")
                        elif uinput2=="2":
                            obj.add_money()
                        elif uinput2=="3":
                            obj.send_money()
                        elif uinput2=="4":
                            obj.Recharge()
                        elif uinput2=="5":
                            obj.view_profile()
                        elif uinput2=="6":
                            obj.edit_profile()
                        elif uinput2=="7" :
                            if len(obj.transaction_history)>0:
                                for i in obj.transaction_history:
                                    print(f"Transaction Id | {i} | Phone Number | {obj.transaction_history[i]['NUMBER']} | Ammount | {obj.transaction_history[i]['AMMOUNT']} | Transaction Type | {obj.transaction_history[i]['TYPE']} | Balance | {obj.transaction_history[i]['BALANCE']}")
                            else:
                                print( " ____________________\n|!!No Records Found!!|\n|____________________|")

                        elif uinput2 =="8":
                            break
                        else:
                            print( " __________________\n|!!Invalid Input !!|\n|__________________|")
            elif uinput=="3":
                break
            else:
                print( " __________________\n|!!Invalid Input !!|\n|__________________|")
    except exception as e:
            print("Oops Something Went Wrong")    
        
if __name__=="__main__":
    print("Welocme To PK Pay\nFINAL DESTINATION OF EVERY PAYMENTS")
    driver_code()
print('Thank You Visit Again')

# %%
import re
class Pkpay:
    def __init__(self):
        self.user_details={}
        self.wallet_money=0
        
    def user_login(self):
        while True:
            phone=("Entre Your Phone Number: \n+91-")
            if phone.isnumeric()==True:
                if len(phone)==10:
                    phone=int(phone)
                    break
                else:
                    print( " __________________\n|!!Invalid Number!!|\n|__________________|")
            else:
                print( " __________________\n|!!Invalid Number!!|\n|__________________|")
        Fname=("Entre Your First Name:\n")
        Mname=("Entre Your Middle Name:\n")
        Lname=("Entre Your Last Name:\n")
        name= Fname+" "+Mname+" "+Lname
        while True:
            regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
            email=("Entre Your Email Id: \n")
            if(re.fullmatch(regex, email)):
                break
            else:
                print( " __________________\n|!!Invalid email!! |\n|__________________|")
        while True:
            password=input("Entre Password")
            Check=False
            if len(password)>=8:
                for i in password:
                    if i in ('@','#','!','$','%','&','^','*','(',')','_','-','+','?','/','~','<','>','*'):
                        Check=True
                    else:
                        pass
                if Check==True:
                    break
                else:
                    print("Password Must Contain Speacal Characters")
        while True:
            DOB:input('Entre Your Birth Date DD/MM/YYYY')
            if DOB[2]=="/" and DOB[5]=="/"
